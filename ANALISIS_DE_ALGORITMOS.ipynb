# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorHerrera10/CC31-Alg-y-estru/blob/main/ANALISIS_DE_ALGORITMOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tarea Académica 2**
#
# ***Ejercicio 1***
#
#
# int s = 0;  //1
#
# double prom = 0; //1
#
# for (int i = 0; i < n; i++) { // 1+n(1+______+2)+1
#
# s = s + A[i]; //3
#
# prom = s / (double) n; // 3
# }
#
# printf("Suma:%d\nProm:%d", s, prom); //2
#
#
# **-----detallado: 1+1+1+n(1+6+2)+1+2 = 9n + 6-----**
#
# **-----asintótico: O(n)-----**
#
#
# ***Ejercicio 2***
#
# int s = 0; //1
#
# double prom = 0; //1
#
# for (int i = 0; i < n; i++) { // 1+n(1+______+2)+1
#
# s = s + A[i]; //3
# }
#
# prom = s / (double)n; //3
#
# printf("Suma:%d\nProm:%d", s, prom); //2
#
#
# **-----detallado: 2+1+n(1+3+2)+1+3+2 = 6n+ 9-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 3***
#
#
# for (int i = 0; i < n - 1; i++) { // 1+n(2+_____+2)+1
#
# for (int k = i + 1; k < n; k++) { // 2+n(1+____+2)+1 = 13n+3
#
# if (vec[i] > vec[k]) { // 3+max(INTERNA IF) = 3+7=10
#
# int aux = vec[i]; //2
#
# vec[i] = vec[k]; //3
#
# vec[k] = aux; // 2
#
# }
#
#
# **-----detallado: 1+n(2+13n+3+2)+1 = 2+n(13n+7)= 2+13n^2+14n = 13n^2 +14n + 2-----**
#
# **-----asintótico: O(n^2)-----**
#
#
#
# ***Ejercicio 4***
#
#
# int frec[101] = {0}; // 2
#
# for (int i = 0; i < n; i++) { // 1+n(1+___+2)+1
#
# frec[vec[i]]++; //5
# }
#
# int pos = 0; // 1
#
# for (int i = 0; i < 101; i++) { // 1+101(1+___+2)+1
#
# for (int k = 0; k < frec[i]; k++) {  // 1+n(2+___+2)+1
#
# vec[pos] = i; //2
#
# pos++; //2
# }
#
# ***1era operacion: 1+n(2+4+2)+1 = 2+n(8)***
#
#
# ***2da operacion: 1+101(1+  2+n(8)  + 2 )+1+1  = 3+101(5+8n)  = 3+505+808n= 508+808n***
#
# ***3cera operacion: 1+n(1+5+2)+1 = 2+8n***
#
# **-----detallado: 2 + 2 + 8n + 508 + 808n = 512 + 816n-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 5***
#
#
#
# int i=0; //1
#
# int sum=0; // 1
#
# while (i < 100) { // 1+1
#
# if (i % 2 == 0) { // 2+ max ( IF INTERNO O ELSE )
#
# for (int k = 0; k < n; k++) { // 1+n(1+___+2)+1 = 1+n(1+3+2)+1 = 2+6n
#
# sum += vec[i]; //3
# }
#
# }
# else {
#
# for (int k=0; k<i; k++) { //1+i(1+___+2)+1 = 1+n(1+3+2)+1= 2+6n
# sum += vec[i]; // 3
# }
#
#
# **-----Mayor complejidad: IF-----**
#
# **-----detallado:2+2+2+2+6n= 8+6n-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercici o6***
#
#
# int fact = 1; //1
#
# for (int i = 2; i < n; i++) { //1+n(1+___+2)+1
#
# fact *= i; //2
# }
#
# printf("Factorial: %d", fact); //1
#
# **-----detallado:1+1+n(1+2+2)+1+1= 5n+4-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 7***
#
#
# int pos = -1; //1
#
# for (int i = 0; i < n; i++) { //1+n(1+___+2)+1
#
# if (strcmp(vec[i], cadBuscar) == 0) { // 3
#
# pos = i;//1
#
# break;
# }
#
# **-----detallado:1+1+n(1+4+2)+1= 7n+3-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 8***
#
# int pos = 0; //1
#
# for (int i = 1; i < n; i++) { //1+n(1+___+2)+1
#
# if (vec[i] > vec[pos]) // 3+max
#
# pos = i;//1
# }
#
# printf("El mayor es: %d", vec[pos]); //2
#
#
# **-----detallado:1+1+n(1+4+2)+1= 3+7n-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 9***
#
# int max = 0; //1
#
# for (int m = 0; m < n; m++) { //1+n(1+____+2)+1 = 1+n(1+1+2)+1+3=  5+4n
#
# int cont = 0; //1
#
# int k = m + 1; // 3
#
# while (vec[m] <= vec[k]) { //4+vec[k](4)= numero x
#
# k = k + 1; //2
#
# cont++;// 2
# }
# if (cont > max) //1+max  = 2
#
# max = cont;// 1
# }
#
# printf("Maximo %d", max); //1
#
# **-----detallado: 1+5+4n+2+1= 9+4n-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 10***
#
#
# int i=1;  //1
#
# while (i < n) { //n(1+___)+1
#
# if (vec[i] % 2 == 0) //3+log(n)
#
# ***i *= 3; //log n ya que está asociado con el while
# else***
#
# ***i *= 2  //log n ya que está asociado con el while
# }***
#
#
# **-----detallado: 1+n(3+log(n))+1= 2+3n+n(log(n))-----**
#
# **-----asintótico: O(n(log(n)))-----**
#
#
#
# ***Ejercicio 11***
#
#
# int i=1; //1
#
# while (i < n) { //n(1+__+___(depende del if))+1
#
# if (vec[i] % 2 == 0) //3
#
# n = n / 3; //2
#
# else
#
# n = n / 2; //2
# }
#
# **-----detallado: 1+n(1+3+2)+1 = 2+6n-----**
#
# **-----asintótico: O(n)-----**
#
#
# ***Ejercicio 12***
#
# int inf = 0; // 1
#
# int sup = n - 1; // 2
#
# int pos = -1; // 1
#
# while ((pos == -1) && (sup >= inf)) { // 1+1+2+n(1+_____+ )+1
#
# int medio = (inf + sup) / 2; // 2
#
# if (arreglo[medio] == 80) // 2+max (2)
#
# pos = medio; //1
#
# else if (arreglo[medio] < 80) //2
#
# inf = medio + 1; // 2
#
# else
# sup = medio - 1; //2
# }
#
# **-----detallado: 1+2+1+1+1+2+n(1+2+2+2)+1 = 9+7n-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 13***
# Encontrar el número mayor en un arreglo de enteros
#
#
#     int arreglo [5] = { 5,8,10,32,2 }; // 1
#     int r = arreglo[0]; // 3
#
#     for (int size_t = 0; size_t < 5 ; size_t++) { // 1+5(1+___+2)+1
#
#         if (r < arreglo[size_t]) // 2+ max
#         r = arreglo[size_t]; //2
#
#     }
#
#     cout << "El numero mayor es: " << r; // 2
#
# **-----detallado: 1+3+1+5(1+4+2)+1+2= 13+5(7)=13+35=48-----**
#
# **-----asintótico: 1 -> Constante!-----**
#
#
#
# ***Ejercicio 14***
# Ordenar un arreglo de números enteros
#
#
#     int Array[100]; int n;int aux; //4
#     cout << "Digite el valor del arreglo: "; cin >> n; //2
#
#     for (int i = 0; i < n; i++) { //1+n(1+____+2)+1
#         cout << "Numero [" << i + 1 << "]: "; cin >> Array[i]; //1+2+1+2= 6
#     }
#
#     for (int i = 0; i < n; i++) { // 1+n(1+___+2)+1
#
#         for (int j = i + 1; j < n; j++) { // 2+n(1+___+2)+1
#
#             if (Array[i] > Array[j]){ //3+ 7= 10
#
#                 aux = Array[i]; //2
#                 Array[i] = Array[j]; //3
#                 Array[j] = aux; // 2
#             }
#         }
#     }
#
#     cout << "\nArreglo ordenado: "; //1
#
#     for (int i = 0; i < n; i++) { //1+n(1+___+2)+1
#         cout << Array[i] << "-"; //3
#     }
#
#  ***fila cout+ 4to for = 1+n(1+3+2)+1+1= 3+n(6)***
#
#  ***3cer for= 2+n(1+10+2)+1 = 2+n(13)+1= 3+n(13)***
#
#  ***2do for= 1+n(1+(3+13n)+2)+1=  2+n(6+13n) = 2+6n+13n^2***
#
#  ***1er for= 1+n(1+6+2)+1= 1+n(9)+1= 2+9n***
#
#  ***Lo primero= 4+2= 6***
#
#
# **-----detallado: 6+2+9n+2+6n+13n^2+3+6n= 21n+13n^2+13-----**
#
# **-----asintótico: O(n^2)-----**
#
#
# ***Ejercicio 15***
# Eliminar el elemento en una posicion de un arreglo
#
#
#
#     unsigned short tam,pos; //unsigned: 2 short: 2 2+2= 4
#     cout << "Escriba el tam del arreglo: "; cin >> tam; // 1+1= 2
#     int arreglo[10]; // 1+1= 2
#
#     for (short i = 0; i < tam; i++) { //1+ n(1+___+2)+1
#         cout << i<<" "; cin >> arreglo[i]; // 1+1+1+1=4
#
#     }
#
#     4+2+2+1+n(1+4+2)+1 = 10+7n
#
#     cout << "Digite la posición del arreglo que desea eliminar: "; cin >> pos;
#     //1+1= 2
#
#     cout << "El arreglo es el siguiente: "; // 1
#     for (short i = 0; i < tam; i++) { // 1+n(1+___+2)+1
#         cout << arreglo[i] << ",";// 3
#     }
#
#     2+1+1+n(1+3+2)+1 = 5+6n
#
#     for (short i = 0; i < tam; i++) { // 1+n(1+___+2)+1
#
#         if (i == pos) { //1
#
#             for (short j = 0; j < tam; j++) { //1+n(1+___+2)+1
#                 arreglo[i] = arreglo[i + 1]; //4
#                                             }
#
#                        }
#
#                                      }
#
#     tam = tam - 1; // 2
#
#     1+n(1+3+7n+2)+1+2= 4+n(6+7n)= 4+6n+7n^2
#
#     cout << "El nuevo arreglo es el siguiente: "; // 1
#     for (short i = 0; i < tam; i++) { // 1+n(1+____+2)+1
#         cout<< arreglo[i] << ","; // 3
#     }
#
#     1+1+n(1+3+2)+1= 3+6n
#
#   **-----detallado: 10+7n+5+6n+4+6n+7n^2+3n+6n = 19+28n+7n^2-----**
#
#   **-----asintótico: O(n^2)-----**
#
#
#
# ***Ejercicio 16***
# Buscar un número en un arreglo
#
#
#     int array[5] = { 10,42,53,23,49 }; //1
#     int numero; //1
#     int pos = 0; //1
#
#     cout << "El siguiente arreglo está compuesto por los siguientes números: "; //1
#     for (int i = 0; i < 5; i++) { //1+5(1+___+2)+1
#         cout << array[i] << " "; // 3
#     }
#     cout << "Que número deseas obtener su posicion?: "; cin >> numero; //2
#
#     for (int i = 0; i < 5; i++) { //1+5(1+___+2)+1
#         if (array[i] == numero) { //2
#             pos = i;//1
#         }
#
#     }
#     cout << "La posicion del numero en el arreglo: " << numero << " es: " << pos; //4
#
#      **-----detallado: 1+1+1+1+1+5(1+3+2)+1+2+1+5(1+3+2)+1+4 = 14+5(6)= 14+30= 44-----**
#   **-----asintótico: 1 ->Constante!-----**
#
#
#
# ***Ejercicio 17***
# Calcular el factorial de N
#
#     int n; //1
#     int resultado=1; //1
#     cout << "Digite su numero: "; cin >> n; //2
#
#     for (int i = 1; i <= n; i++) { //1+n(2+___+2)+1
#
#         if (i <=n ) { //2
#             resultado *= i;//2
#         }
#
#     }
#
#     cout << "El factorial del numero es: " << resultado; //2
#
#   **-----detallado: 1+1+2+1+n(2+4+2)+1+2 = 8+8n-----**
#
#   **-----asintótico: O(n)-----**
#
#
# ***Ejercicio 18***
# Determinar si un número existe en un arreglo de enteros.
#
#
#     srand(time(NULL));
#
#     unsigned int arreglo[100]; //2
#     unsigned int numero; //2
#     unsigned int tam; //2
#     short aux = 0; //1
#
#     cout << "Tamaño del arreglo: "; cin >> tam; //2
#
#     for (int i = 0; i < tam; i++) { //1+n(1+____+2)+1
#         arreglo[i] = rand()%101; //3
#     }
#
#     cout << "Digite el numero que desea saber si existe: "; cin >> numero; //2
#     cout << "El arreglo de numeros es el siguiente: "; //1
#     for (int i = 0; i < tam; i++) { //1+n(1+___2)+1
#         cout << arreglo[i] << ","; //3
#         if (numero == arreglo[i])aux++; //4
#     }
#
#     if (aux >= 1) { //2+max
#         cout << "\nPor tanto el numero si existe";//1
#     }
#     else {
#         cout << "\nPor tanto el numero no existe";//1
#     }
#
#   **-----detallado: 2+2+2+1+2+1+n(1+3+2)+1+2+1+1+n(1+7+2)+1+2+1=  15+16n-----**
#
#   **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 19***
# Calcular cuántas veces se repite un número X en un arreglo de enteros.
#
#
#     srand(time(NULL));
#
#     int arreglo[200]; //1
#     int n; //1
#     int aux = 0; //1
#     cout << "Digita el numero: "; cin >> n; //2
#     for (int i = 0; i < 200; i++) { 1+200(1+___+2)+1
#         arreglo[i] = rand() % 200; // 3
#     }
#     for (int i = 0; i < 200; i++) { //1+200(1+__+2)+1
#         if (arreglo[i] == n)aux++; //4
#     }
#
#     if (aux >= 1)cout << "El numero aparece " << aux << " vez/veces en el arreglo"; // 2+2
#
#   **-----detallado: 1+1+1+2+1+200(1+3+2)+1+1+200(1+4+2)+1+4 =  13+200(6)+200(7) = 2613-----**
#   **-----asintótico: 1-> Constante!-----**
#
#
#
# ***Ejercicio 20***
# Sumar los dígitos de un número entero positivo.
#
#
#     unsigned int n; //2
#     int suma = 0; // 1
#     cout << "Numero: "; cin >> n; //2
#
#     while (n > 0) { //n(__)+1
#         suma += n % 10; //3
#         n /= 10; // 2
#     }
#
#     cout << "Suma Digitos: " << suma; //2
#
#   **-----detallado: 2+1+2+n(5)+1+2 = 8+5n-----**
#
#   **-----asintótico: O(n)-----**
#
#
# ***Ejercicio 21***
# Determinar si un número es primo o no.
#
#     int numero; //1
#     int aux=0; //1
#     cout << "Digite numero: "; cin >> numero; //2
#
#     for (int i = 1; i <= numero; i++) { //1+n(2+___+2)+1
#
#         if ((numero % i == 0))aux++; // 4
#
#     }
#     if (aux == 2)//1
#     cout << "El numero es primo"; //1
#      else cout << "El numero no es primo"; //1
#
# **-----detallado: 1+1+2+1+n(2+4+2)+1+1+1=  8+8n-----**
#
# **-----asintótico: O(n)-----**
#
#
#
# ***Ejercicio 22***
# Determinar la cantidad de primos que existen en un arreglo de enteros.
#
#
#     srand(time(NULL));
#     int arregloenteros[50]; //1
#     int aux=0; //1
#     int cont = 0; // 1
#
#     for (int i = 0; i < 50; i++) { //1+50(1+___+2)+1 =   1+50(1+3+2)+1 =  2+50(6)= 302
#         arregloenteros[i] = rand() % 500; // 3
#     }
#
#     for (int i = 0; i < 50; i++) { //1+50(1+___+2)+1  =  1+50(1+6+9n+2)+1+3 =  5+50(9+9n)
#         cout << arregloenteros[i] << " "; //3
#
#         for (int j = 1; j <= arregloenteros[i]; j++) { //1+n(2+___+2)+1  =   1+n(2+5+2)+1+1+2+1 = 6+9n
#
#             if ((arregloenteros[i] % j == 0)) {// 3
#
#                 aux++;//2
#
#             }
#
#          }
#
#         if (aux == 2) {// 1
#             cont++;//2
#             aux = 0;//1
#         }
#
#     }
#
#     cout << "Numeros primos en el arreglo: " << cont; //2
#
#
#
#   **-----detallado: 1+1+1+302+5+50(9+9n)= 311+450+450n= 761+450n-----**
#
#   **-----asintótico: O(n)-----**
